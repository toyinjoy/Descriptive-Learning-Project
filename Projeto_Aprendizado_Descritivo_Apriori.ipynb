# %% [markdown]
# <a href="https://colab.research.google.com/github/toyinjoy/Descriptive-Learning-Project/blob/main/Projeto_Aprendizado_Descritivo_Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descriptive Learning Project
#
# This notebook is part of a project exploring frequent pattern mining and subgroup discovery on hospitalization data from Brazil’s Unified Health System (SUS). Using Apriori algorithm from PyFim and WRAcc-based subgroup discovery, we identified meaningful patterns and patient segments associated with mortality, cost, and length of stay.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preparation

# %%
# Instalando o kagglehub se ainda não estiver instalado
# !pip install kagglehub --quiet

# Fazendo o download do dataset BigSUS SIH Silver (base hospitalar do SUS)
import kagglehub

# Baixando o dataset
path = kagglehub.dataset_download("victoremanuel/bigsus-sih-silver")

# Exibindo o caminho dos arquivos baixados
print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/victoremanuel/bigsus-sih-silver?dataset_version_number=5...
# 100%|██████████| 5.92G/5.92G [02:34<00:00, 41.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5

# %%
# Filtrando dados de interesse a ser analisada

pastas_validas = []

for p in sorted(os.listdir(path)):
    if p.isdigit() and int(p) >= 201901:
        pasta_completa = os.path.join(path, p)
        if os.path.isdir(pasta_completa):
            arquivos = [f for f in os.listdir(pasta_completa) if f.endswith(".parquet")]
            if arquivos:
                pastas_validas.append(p)

# %%
# Selecionando apenas as colunas a serem utilizadas
colunas = [
    "SEXO", "IDADE", "CAR_INT", "UF_ZI",
    "DIAG_PRINC", "MORTE", "DIAS_PERM", "VAL_TOT"
]

# %%
# Criando o dataframe para exploração dos dados
dfs = []

for pasta in pastas_validas:
    caminho_pasta = os.path.join(path, pasta)
    arquivos = [f for f in os.listdir(caminho_pasta) if f.endswith(".parquet")]

    for arquivo in arquivos:
        caminho_arquivo = os.path.join(caminho_pasta, arquivo)
        print(f"Lendo {caminho_arquivo}")
        df = pd.read_parquet(caminho_arquivo, columns=colunas)
        dfs.append(df)

# Concatena todos os dados reduzidos
df_filtrado = pd.concat(dfs, ignore_index=True)
# Out:
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDTO1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDMG1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDBA1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDAC1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDRR1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDES1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDRS1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDSC1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDMA1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDRN1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDMT1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDCE1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDAM1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDDF1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDPA1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDMS1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDPE1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDAL1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDPB1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDRJ1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDRO1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDSE1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDSP1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDGO1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDPR1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDAP1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201901/RDPI1901.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDAL1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDMA1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDRR1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDES1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDPI1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDSC1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDRN1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDGO1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDRS1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDAP1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDAC1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDSP1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDDF1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDPA1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDPR1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDSE1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDBA1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDAM1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDRJ1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDPB1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDTO1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDCE1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDRO1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDPE1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDMS1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDMG1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201902/RDMT1902.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDPB1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDAM1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDPA1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDAC1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDPE1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDAP1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDBA1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDMA1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDMG1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDTO1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDPI1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDCE1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDRO1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDPR1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDSP1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDAL1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDES1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDRS1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDGO1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDMT1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDRR1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDDF1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDSC1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDRN1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDRJ1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDMS1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201903/RDSE1903.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDRO1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDTO1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDPE1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDMG1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDPB1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDSC1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDMA1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDAC1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDAP1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDRN1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDAL1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDSP1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDMT1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDCE1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDPR1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDES1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDDF1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDRJ1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDMS1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDPI1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDRR1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDBA1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDPA1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDRS1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDAM1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDSE1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201904/RDGO1904.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDPA1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDRO1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDAP1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDPR1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDAC1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDMS1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDPB1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDBA1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDAL1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDGO1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDSP1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDRJ1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDRS1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDSC1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDRR1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDMG1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDTO1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDAM1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDDF1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDES1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDPE1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDPI1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDRN1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDCE1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDSE1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDMT1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201905/RDMA1905.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDPB1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDSE1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDMG1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDDF1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDTO1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDBA1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDAP1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDGO1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDRR1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDPR1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDPI1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDAM1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDSP1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDMA1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDRO1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDRS1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDAC1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDSC1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDMS1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDMT1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDRN1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDRJ1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDPA1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDPE1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDAL1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDES1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201906/RDCE1906.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDMS1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDAP1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDCE1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDTO1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDSE1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDMA1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDMG1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDBA1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDAL1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDSP1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDGO1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDPA1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDMT1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDSC1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDRS1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDRR1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDES1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDRO1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDPR1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDAM1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDPE1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDRN1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDRJ1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDPI1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDAC1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDDF1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201907/RDPB1907.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDPB1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDES1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDMG1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDRN1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDDF1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDMS1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDRR1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDMA1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDRS1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDSE1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDSC1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDBA1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDMT1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDPE1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDAC1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDCE1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDPA1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDTO1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDPI1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDRO1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDAM1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDAP1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDRJ1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDSP1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDPR1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDAL1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201908/RDGO1908.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDAC1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDPR1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDPA1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDSP1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDSC1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDMA1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDSE1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDMS1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDRO1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDRR1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDRJ1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDPI1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDBA1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDPB1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDPE1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDCE1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDDF1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDMG1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDTO1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDES1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDRS1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDAP1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDAM1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDMT1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDGO1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDRN1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201909/RDAL1909.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDAM1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDBA1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDMT1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDRJ1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDRR1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDGO1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDAP1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDRN1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDTO1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDPR1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDPB1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDES1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDMG1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDPA1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDPI1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDRS1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDMA1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDPE1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDMS1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDRO1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDAC1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDSC1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDSP1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDSE1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDDF1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDCE1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201910/RDAL1910.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDRS1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDPA1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDMA1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDMG1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDSE1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDSP1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDAL1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDTO1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDRR1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDPI1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDSC1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDPE1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDAP1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDBA1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDAC1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDMT1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDRJ1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDAM1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDPR1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDES1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDDF1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDCE1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDRO1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDMS1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDGO1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDRN1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201911/RDPB1911.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDPR1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDMS1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDAC1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDPB1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDPA1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDAM1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDSP1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDBA1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDRR1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDTO1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDRJ1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDRN1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDPI1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDGO1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDSE1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDCE1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDMG1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDRO1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDMT1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDPE1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDRS1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDAP1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDMA1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDES1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDAL1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDSC1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/201912/RDDF1912.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDSP2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDMG2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDRS2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDMT2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDCE2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDPI2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDRJ2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDRN2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDSC2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDPB2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDMS2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDES2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDPE2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDPR2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDTO2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDRO2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDAP2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDMA2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDDF2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDPA2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDSE2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDGO2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDBA2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDAC2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDRR2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDAM2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202001/RDAL2001.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDSE2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDTO2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDPB2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDMT2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDSC2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDRR2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDRJ2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDPR2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDSP2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDPE2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDRS2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDMA2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDCE2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDPA2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDMS2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDPI2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDRO2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDAM2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDRN2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDGO2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDES2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDDF2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDBA2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDAC2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDAL2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDMG2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202002/RDAP2002.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDAP2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDES2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDMT2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDDF2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDSE2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDSP2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDPI2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDRR2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDMG2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDRJ2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDCE2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDPA2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDGO2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDBA2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDRO2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDRN2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDTO2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDAC2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDMS2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDRS2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDAL2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDAM2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDMA2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDPR2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDPE2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDPB2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202003/RDSC2003.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDCE2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDPA2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDAC2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDSP2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDMA2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDAL2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDSC2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDRR2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDBA2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDDF2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDRS2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDAM2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDSE2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDMS2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDRJ2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDPI2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDPB2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDPE2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDGO2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDRO2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDPR2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDAP2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDMT2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDMG2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDTO2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDRN2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202004/RDES2004.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDAL2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDDF2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDPE2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDMA2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDMG2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDPA2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDSP2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDTO2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDMS2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDES2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDGO2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDPR2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDMT2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDRR2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDCE2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDRO2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDBA2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDRN2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDAC2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDAP2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDPB2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDSE2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDRJ2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDRS2005.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202005/RDPI2005.parquet
# ...
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDMT2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDSC2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDBA2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDAL2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDSE2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDGO2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDRO2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDAC2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDPB2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDRR2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDMS2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDRS2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDAP2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDRJ2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDES2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDMA2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDDF2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202411/RDAM2411.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDRR2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDRO2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDAC2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDRN2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDAM2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDRS2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDAL2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDBA2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDGO2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDPI2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDSC2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDTO2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDAP2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDMG2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDRJ2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDPA2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDMS2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDCE2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDPR2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDDF2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDES2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDSP2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDSE2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDMT2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDMA2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDPE2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202412/RDPB2412.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDAL2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDAM2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDPE2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDMG2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDAC2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDRJ2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDMT2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDGO2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDRN2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDPR2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDPI2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDRO2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDSC2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDES2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDPA2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDBA2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDAP2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDRS2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDRR2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDSE2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDMA2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDMS2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDSP2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDDF2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDCE2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDPB2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202501/RDTO2501.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDPI2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDPB2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDPR2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDSC2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDAL2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDGO2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDPA2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDMG2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDSP2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDCE2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDES2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDRO2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDAP2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDPE2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDMA2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDMS2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDRS2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDMT2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDBA2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDAC2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDRR2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDSE2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDAM2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDRN2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDTO2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDDF2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202502/RDRJ2502.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDGO2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDMS2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDPB2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDPA2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDSE2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDBA2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDRR2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDMA2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDDF2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDRN2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDAC2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDPE2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDAP2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDSP2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDAL2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDPR2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDRO2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDTO2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDSC2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDES2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDAM2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDMT2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDRJ2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDPI2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDRS2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDCE2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202503/RDMG2503.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDPR2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDDF2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDAL2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDRO2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDPE2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDES2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDPB2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDAP2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDSE2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDSP2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDRR2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDRJ2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDMT2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDPA2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDCE2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDMS2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDGO2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDRS2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDMA2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDPI2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDSC2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDMG2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDBA2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDTO2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDAM2504.parquet
# Lendo /root/.cache/kagglehub/datasets/victoremanuel/bigsus-sih-silver/versions/5/202504/RDRN2504.parquet

# %%
# Força conversão de Valor Total para número
df_filtrado["VAL_TOT"] = pd.to_numeric(df_filtrado["VAL_TOT"], errors="coerce")

# %%
# Obtendo descrição estatística dos dados
df_filtrado.describe()
# Out:
#               IDADE         MORTE     DIAS_PERM       VAL_TOT
# count  7.926896e+07  7.926896e+07  7.926896e+07  7.926896e+07
# mean   4.211380e+01  4.918813e-02  5.188668e+00  1.587498e+03
# std    2.424350e+01  2.162606e-01  7.523166e+00  3.998602e+03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.300000e+01  0.000000e+00  1.000000e+00  3.568100e+02
# 50%    4.000000e+01  0.000000e+00  3.000000e+00  6.285700e+02
# 75%    6.200000e+01  0.000000e+00  6.000000e+00  1.139600e+03
# max    9.900000e+01  1.000000e+00  3.640000e+02  2.742075e+05

# %%
# Verificando informações do dataset gerado
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79268957 entries, 0 to 79268956
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   SEXO        object
#  1   IDADE       int8
#  2   CAR_INT     object
#  3   UF_ZI       object
#  4   DIAG_PRINC  object
#  5   MORTE       int8
#  6   DIAS_PERM   int32
#  7   VAL_TOT     float64
# dtypes: float64(1), int32(1), int8(2), object(4)
# memory usage: 3.4+ GB

# %%
# Verificando existência de valores nulos
df_filtrado.isnull().sum()
# Out:
# SEXO          0
# IDADE         0
# CAR_INT       0
# UF_ZI         0
# DIAG_PRINC    0
# MORTE         0
# DIAS_PERM     0
# VAL_TOT       0
# dtype: int64

# %%
# Avaliando quantidade de valores únicos
df_filtrado.nunique()
# Out:
# SEXO                2
# IDADE             100
# CAR_INT             6
# UF_ZI            2454
# DIAG_PRINC      10438
# MORTE               2
# DIAS_PERM         351
# VAL_TOT       2176154
# dtype: int64

# %%
# Definição das categorias para variáveis idade, dias de permanência e valor de internação
bins_idade = [0, 9, 19, 29, 39, 49, 59, 69, 79, 89, 150]
labels_idade = ["0-9","10-19","20-29","30-39","40-49","50-59","60-69","70-79","80-89","90+"]

bins_perm = [0, 1, 3, 7, 15, 30, 999]
labels_perm = ["1","2-3","4-7","8-15","16-30","31+"]

bins_valor = [0, 1000, 3000, 10000, 30000, 9999999]
labels_valor = ["0-999","1K-3K","3K-10K","10K-30K","30K+"]

# %%
# Categorizando colunas numéricas
df_filtrado["IDADE_CAT"] = pd.cut(df_filtrado["IDADE"], bins=bins_idade, labels=labels_idade, right=False)
df_filtrado["PERM_CAT"] = pd.cut(df_filtrado["DIAS_PERM"], bins=bins_perm, labels=labels_perm, right=False)
df_filtrado["VAL_CAT"] = pd.cut(df_filtrado["VAL_TOT"], bins=bins_valor, labels=labels_valor, right=False)

# %%
df_filtrado.head()
# Out:
#   SEXO  IDADE CAR_INT   UF_ZI DIAG_PRINC  MORTE  DIAS_PERM  VAL_TOT IDADE_CAT  \
# 0    3     22      02  170000       Z302      0          2   695.46     20-29
# 1    3     31      02  170000       O335      0          3   638.26     30-39
# 2    3     25      02  170000       Z302      0          2   695.46     20-29
# 3    3     33      02  170000       O021      0          2   185.97     30-39
# 4    3     35      02  170000       Z302      0          3   703.46     30-39
#
#   PERM_CAT VAL_CAT
# 0      2-3   0-999
# 1      4-7   0-999
# 2      2-3   0-999
# 3      2-3   0-999
# 4      4-7   0-999

# %%
df_filtrado.shape
# Out:
# (79268957, 11)

# %% [markdown]
# #Frequent Pattern Mining

# %%
# !pip install pyfim
# Out:
# Collecting pyfim
#   Downloading pyfim-6.28.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyfim
#   Building wheel for pyfim (setup.py) ... done
#   Created wheel for pyfim: filename=pyfim-6.28-cp311-cp311-linux_x86_64.whl size=647123 sha256=d2f98eeaa95246c9907d8d8bef96c909bd420fecbccb830204c7ea3fdd1c7970
#   Stored in directory: /root/.cache/pip/wheels/aa/a6/5e/b106c510135fd055b238ecf87738098dc7ad3a1f056dd5208e
# Successfully built pyfim
# Installing collected packages: pyfim
# Successfully installed pyfim-6.28

# %%
# !pip install --quiet mlxtend pandas numpy

# %%
from fim import apriori

# %%
# 3% sample of 79M = ~2.37M rows
df_sample = df_filtrado.sample(frac=0.03, random_state=42)
print(df_sample.shape)
# Out:
# (2378069, 11)

# %%
def row_to_items(row):
    return [
        f"SEXO={row['SEXO']}",
        f"IDADE={row['IDADE_CAT']}",
        f"CARE={row['CAR_INT']}",
        f"STATE={row['UF_ZI']}",
        f"DX={row['DIAG_PRINC']}",
        f"LOS={row['PERM_CAT']}",
        f"COST={row['VAL_CAT']}"
        #f"MORT={row['MORTE']}",
    ]

transactions = df_sample.apply(row_to_items, axis=1).tolist()

# %%
# Set minimum support to 1% of sample size
min_supp = int(0.00001 * len(transactions))

# Run FP-Growth directly on the list-of-lists
patterns = apriori(
    transactions,
    supp=min_supp,         # absolute support count
    zmin=2,                # min items in pattern
    zmax=5,                # max items in pattern
    report='aS'            # return (items, absolute support, relative support)
)

# %%
print("Total patterns found:", len(patterns))   # likely 0
# Out:
# Total patterns found: 11

# %%
print("Top 10 frequent patterns:")
for items, count, support in patterns[:10]:
    print(f"{items} → support: {support:.4f} ({count} rows)")
# Out:
# Top 10 frequent patterns:
# ('LOS=4-7', 'CARE=02') → support: 26.0211 (618799 rows)
# ('LOS=2-3', 'SEXO=3') → support: 25.9320 (616681 rows)
# ('LOS=2-3', 'COST=0-999') → support: 32.9221 (782911 rows)
# ('LOS=2-3', 'COST=0-999', 'CARE=02') → support: 25.6080 (608976 rows)
# ('LOS=2-3', 'CARE=02') → support: 28.9968 (689565 rows)
# ('SEXO=1', 'COST=0-999') → support: 27.8087 (661310 rows)
# ('SEXO=1', 'CARE=02') → support: 32.3491 (769284 rows)
# ('SEXO=3', 'COST=0-999') → support: 42.8601 (1019242 rows)
# ('SEXO=3', 'COST=0-999', 'CARE=02') → support: 35.1236 (835264 rows)
# ('SEXO=3', 'CARE=02') → support: 44.9953 (1070019 rows)

# %%
mortal_patterns = [p for p in patterns if 'MORT=1' in p[0]]
for items, count, support in mortal_patterns[:10]:
    print(f"{items} → support: {support:.4f} ({count} rows)")

# %%
# Keep only rows where patient died
df_mort = df_filtrado[df_filtrado['MORTE'] == 1]

# Convert to transactions
transactions_mort = df_mort.apply(row_to_items, axis=1).tolist()

# Mine just within this subset
patterns_mort = apriori(transactions_mort, supp=20, zmin=2, zmax=5, report='aS')

print("Top mortality-only patterns:")
for items, count, support in patterns_mort[:10]:
    print(f"{items} → support: {support:.4f} ({count} rows)")
# Out:
# Top mortality-only patterns:
# ('LOS=2-3', 'CARE=02') → support: 20.7394 (808649 rows)
# ('IDADE=70-79', 'CARE=02') → support: 21.6978 (846019 rows)
# ('LOS=8-15', 'CARE=02') → support: 23.5103 (916687 rows)
# ('LOS=4-7', 'CARE=02') → support: 23.9987 (935731 rows)
# ('COST=1K-3K', 'CARE=02') → support: 24.7675 (965706 rows)
# ('COST=0-999', 'SEXO=1') → support: 20.6552 (805365 rows)
# ('COST=0-999', 'CARE=02') → support: 37.2928 (1454079 rows)
# ('SEXO=3', 'CARE=02') → support: 42.7548 (1667049 rows)
# ('SEXO=1', 'CARE=02') → support: 49.2510 (1920343 rows)

# %%
df_mort.shape
# Out:
# (3899092, 11)

# %%
print("Total patterns found:", len(patterns_mort))
# Out:
# Total patterns found: 9

# %%
# Keep only rows where patient survived
df_survived= df_filtrado[df_filtrado['MORTE'] == 0]

# %%
df_surv_sample = df_survived.sample(frac=0.4, random_state=42)
print(df_surv_sample.shape)
# Out:
# (30147946, 11)

# %%
30147946 + 3899092
# Out:
# 34047038

# %%
# Convert to transactions
transactions_surv_sample = df_surv_sample.apply(row_to_items, axis=1).tolist()

# Mine just within this subset
patterns_surv_sample = apriori(transactions_surv_sample ,supp=20, zmin=2, zmax=5, report='aS')

print("Top Surviving-only patterns:")
for items, count, support in patterns_surv_sample[:10]:
    print(f"{items} → support: {support:.4f} ({count} rows)")
# Out:
# Top Surviving-only patterns:
# ('LOS=4-7', 'COST=0-999') → support: 22.2593 (6710722 rows)
# ('LOS=4-7', 'COST=0-999', 'CARE=02') → support: 20.3834 (6145171 rows)
# ('LOS=4-7', 'CARE=02') → support: 26.1369 (7879751 rows)
# ('LOS=2-3', 'SEXO=3') → support: 26.7488 (8064217 rows)
# ('LOS=2-3', 'SEXO=3', 'COST=0-999') → support: 22.8228 (6880591 rows)
# ('LOS=2-3', 'COST=0-999') → support: 34.0199 (10256313 rows)
# ('LOS=2-3', 'COST=0-999', 'CARE=02') → support: 26.3495 (7943829 rows)
# ('LOS=2-3', 'CARE=02') → support: 29.4505 (8878735 rows)
# ('SEXO=1', 'COST=0-999') → support: 28.2233 (8508758 rows)
# ('SEXO=1', 'COST=0-999', 'CARE=02') → support: 21.4056 (6453352 rows)

# %%
print("Total patterns found:", len(patterns_surv_sample))
# Out:
# Total patterns found: 15

# %%
cols = ['items', 'count', 'support']
df_pat_mort = pd.DataFrame(patterns_mort, columns=cols)
df_pat_surv = pd.DataFrame(patterns_surv_sample, columns=cols)

# %%
df_pat_mort.head()
# Out:
#                     items   count    support
# 0      (LOS=2-3, CARE=02)  808649  20.739418
# 1  (IDADE=70-79, CARE=02)  846019  21.697847
# 2     (LOS=8-15, CARE=02)  916687  23.510269
# 3      (LOS=4-7, CARE=02)  935731  23.998690
# 4   (COST=1K-3K, CARE=02)  965706  24.767459

# %%
df_pat_surv.head()
# Out:
#                             items    count    support
# 0           (LOS=4-7, COST=0-999)  6710722  22.259301
# 1  (LOS=4-7, COST=0-999, CARE=02)  6145171  20.383382
# 2              (LOS=4-7, CARE=02)  7879751  26.136941
# 3               (LOS=2-3, SEXO=3)  8064217  26.748811
# 4   (LOS=2-3, SEXO=3, COST=0-999)  6880591  22.822752

# %%
df_mort = df_pat_mort
df_surv = df_pat_surv


n_mort = df_mort['count'].sum()
n_surv = df_surv['count'].sum()

#  Compute support (%) for each group

df_mort['support_pct'] = df_mort['count'] / n_mort * 100
df_surv['support_pct'] = df_surv['count'] / n_surv * 100


# Split into common / exclusive sets

set_mort, set_surv = set(df_mort['items']), set(df_surv['items'])
common_items       = set_mort & set_surv
mort_only_items    = set_mort - set_surv
surv_only_items    = set_surv - set_mort

df_common = pd.merge(
        df_mort[df_mort['items'].isin(common_items)][['items','support_pct']],
        df_surv[df_surv['items'].isin(common_items)][['items','support_pct']],
        on='items', how='inner', suffixes=('_mort','_surv')
)

df_mort_only = (df_mort[df_mort['items'].isin(mort_only_items)]
                .nlargest(10, 'support_pct'))
df_surv_only = (df_surv[df_surv['items'].isin(surv_only_items)]
                .nlargest(10, 'support_pct'))

short = lambda tpl: ' · '.join(tpl)


# COMMON PATTERNS — line plot

plt.figure(figsize=(14,5))
x = range(len(df_common))

plt.plot(x, df_common['support_pct_mort'], marker='o', color='red',   label='Deaths')
plt.plot(x, df_common['support_pct_surv'], marker='o', color='green', label='Survivors')

plt.xticks(x, [short(t) for t in df_common['items']], rotation=45, ha='right')
plt.ylabel('Support (%)')
plt.title('Patterns present in BOTH groups')
plt.legend()
plt.tight_layout()
plt.show()


# SURVIVOR-ONLY — top-10 line plot

plt.figure(figsize=(14,4))
x = range(len(df_surv_only))
plt.plot(x, df_surv_only['support_pct'], marker='o', color='green')
plt.xticks(x, [short(t) for t in df_surv_only['items']], rotation=45, ha='right')
plt.ylabel('Support (%)')
plt.title('Top-10 SURVIVOR-only patterns')
plt.tight_layout()
plt.show()


#   DEATH-ONLY — top-10 line plot

plt.figure(figsize=(14,4))
x = range(len(df_mort_only))
plt.plot(x, df_mort_only['support_pct'], marker='o', color='red')
plt.xticks(x, [short(t) for t in df_mort_only['items']], rotation=45, ha='right')
plt.ylabel('Support (%)')
plt.title('Top-10 DEATH-only patterns')
plt.tight_layout()
plt.show()

# %% [markdown]
# # compare patterns across sexo and idade

# %%
target_rows = 34_000_000
sample_size = min(target_rows, len(df_filtrado))
df_samp = df_filtrado.sample(n=sample_size, random_state=42)

print(f"Sample size: {len(df_samp):,} rows")


# Count deaths vs survivors in the sample

mort_counts = (
    df_samp['MORTE']
      .value_counts(dropna=False)
      .rename({0: 'Survivors (MORTE=0)',
               1: 'Deaths (MORTE=1)'})
      .to_frame(name='rows')
)

mort_counts['share_%'] = (mort_counts['rows'] / sample_size * 100).round(2)
print("\nMORTE distribution in sample")
print(mort_counts)


sexo_map = {1: 'Male', 3: 'Female'}        # adjust if other codes exist
df_samp['SEXO_LABEL'] = df_samp['SEXO'].map(sexo_map).fillna(df_samp['SEXO'].astype(str))


# modal COST band per Age × Sex
pivot_cost = pd.pivot_table(df_samp,
                            values='VAL_CAT',
                            index='IDADE_CAT',
                            columns='SEXO_LABEL',
                            aggfunc=lambda x: x.value_counts().idxmax())

# modal LOS band per Age × Sex
pivot_los = pd.pivot_table(df_samp,
                           values='PERM_CAT',
                           index='IDADE_CAT',
                           columns='SEXO_LABEL',
                           aggfunc=lambda x: x.value_counts().idxmax())

# mortality rate (%)
mort_rate = (
    df_samp
      .groupby(['IDADE_CAT', 'SEXO_LABEL'])['MORTE']
      .mean()
      * 100
).unstack()


# Display tables

print("\nModal COST band (VAL_CAT) by Age × Sex")
display(pivot_cost)

print("\nModal Length-of-Stay band (PERM_CAT) by Age × Sex")
display(pivot_los)

print("\nMortality rate (% admissions that died) by Age × Sex")
display(mort_rate.round(2))
# Out:
# Sample size: 34,000,000 rows
#
# MORTE distribution in sample
#                          rows  share_%
# MORTE
# Survivors (MORTE=0)  32327500    95.08
# Deaths (MORTE=1)      1672500     4.92
# /tmp/ipython-input-36-2764435699.py:43: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_cost = pd.pivot_table(df_samp,
# /tmp/ipython-input-36-2764435699.py:50: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_los = pd.pivot_table(df_samp,
# /tmp/ipython-input-36-2764435699.py:59: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['IDADE_CAT', 'SEXO_LABEL'])['MORTE']
# Modal COST band (VAL_CAT) by Age × Sex
# SEXO_LABEL      1      3
# IDADE_CAT
# 0-9         0-999  0-999
# 10-19       0-999  0-999
# 20-29       0-999  0-999
# 30-39       0-999  0-999
# 40-49       0-999  0-999
# 50-59       0-999  0-999
# 60-69       0-999  0-999
# 70-79       0-999  0-999
# 80-89       0-999  0-999
# 90+         0-999  0-999
# Modal Length-of-Stay band (PERM_CAT) by Age × Sex
# SEXO_LABEL    1    3
# IDADE_CAT
# 0-9         4-7  4-7
# 10-19       2-3  2-3
# 20-29       2-3  2-3
# 30-39       2-3  2-3
# 40-49       2-3  2-3
# 50-59       2-3  2-3
# 60-69       2-3  2-3
# 70-79       4-7  4-7
# 80-89       4-7  4-7
# 90+         4-7  4-7
# Mortality rate (% admissions that died) by Age × Sex
# SEXO_LABEL      1      3
# IDADE_CAT
# 0-9          1.55   1.81
# 10-19        0.86   0.45
# 20-29        1.70   0.29
# 30-39        2.37   0.71
# 40-49        3.69   2.26
# 50-59        5.88   4.68
# 60-69        8.50   7.49
# 70-79       12.08  11.10
# 80-89       17.57  16.79
# 90+         24.30  24.44

# %%
#  Heatmap for Mortality + Annotated Text Grids for Band Modes

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

#  Mortality Rate (numerical)
sns.heatmap(mort_rate.sort_index(), annot=True, fmt=".1f",
            cmap='Reds', ax=axes[0])
axes[0].set_title("Mortality Rate (%)")
axes[0].set_xlabel("Sex")
axes[0].set_ylabel("Age band")

# Cost Band Grid (categorical)
axes[1].axis('off')
table_cost = pd.DataFrame(pivot_cost).sort_index()
axes[1].table(cellText=table_cost.values,
              rowLabels=table_cost.index,
              colLabels=table_cost.columns,
              cellLoc='center', loc='center')
axes[1].set_title("Modal Cost Band (VAL_CAT)")

# Length of Stay Grid (categorical)
axes[2].axis('off')
table_los = pd.DataFrame(pivot_los).sort_index()
axes[2].table(cellText=table_los.values,
              rowLabels=table_los.index,
              colLabels=table_los.columns,
              cellLoc='center', loc='center')
axes[2].set_title("Modal Length of Stay Band (PERM_CAT)")

plt.tight_layout()
plt.show()
